# %% [markdown]
# # 파일 호출 / 저장

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/MLStudy/ch03_data_preprocessing/13_file_load_save_data/fruit.csv')

# %%
df.head(10)     # 처음부터 n행 출력, 기본값은 5행
# Out:
#    Unnamed: 0   품목 크기    금액    수수료
# 0           0  바나나  중  2000  200.0
# 1           1  바나나  대  3000  300.0
# 2           2  바나나  중  2000  200.0
# 3           3  토마토  대  1500  150.0
# 4           4  토마토  소   500   50.0
# 5           5   사과  중  3000  300.0
# 6           6  바나나  대  3000  300.0
# 7           7   사과  중  3000  300.0
# 8           8  토마토  대  1500  150.0
# 9           9  토마토  소   500   50.0

# %%
df.tail()     # 뒤에서부터 5행 출력
# Out:
#     Unnamed: 0   품목 크기    금액    수수료
# 51          51   사과  대  4000  400.0
# 52          52   사과  소  2000  200.0
# 53          53  토마토  대  1500  150.0
# 54          54   사과  소  2000  200.0
# 55          55  토마토  대  1500  150.0

# %% [markdown]
# 첫 번째 열을 인덱스열로 삼고싶은 경우

# %%
df = pd.read_csv('/content/drive/MyDrive/MLStudy/ch03_data_preprocessing/13_file_load_save_data/fruit.csv', index_col=0)

# %%
df.head()
# Out:
#     품목 크기    금액    수수료
# 0  바나나  중  2000  200.0
# 1  바나나  대  3000  300.0
# 2  바나나  중  2000  200.0
# 3  토마토  대  1500  150.0
# 4  토마토  소   500   50.0

# %% [markdown]
# csv 파일이 아닌 경우

# %%
df = pd.read_csv('/content/drive/MyDrive/MLStudy/ch03_data_preprocessing/13_file_load_save_data/read_sep.txt', index_col=0, sep='|')

# %%
df.head()
# Out:
#        A   B   C
# index
# 0      1  11  21
# 1      2  12  22
# 2      3  13  23

# %% [markdown]
# header가 여러 줄인 경우

# %%
df = pd.read_csv('/content/drive/MyDrive/MLStudy/ch03_data_preprocessing/13_file_load_save_data/multi_header.csv', header=1)

# %%
df
# Out:
#    a   b   c
# 0  1  11  21
# 1  2  12  22
# 2  3  13  23
# 3  4  14  24

# %%
df.columns
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %% [markdown]
# 데이터를 읽으면서 칼럼명을 추가하고 싶을 때

# %%
df = pd.read_csv('/content/drive/MyDrive/MLStudy/ch03_data_preprocessing/13_file_load_save_data/fruit_no_column.csv', index_col=0, names=['품목', '크기', '금액', '수수료'])
df.head()
# Out:
#     품목 크기    금액    수수료
# 0  바나나  중  2000  200.0
# 1  바나나  대  3000  300.0
# 2  바나나  중  2000  200.0
# 3  토마토  대  1500  150.0
# 4  토마토  소   500   50.0

# %% [markdown]
# 원하는 칼럼만 쓰고 싶을 때

# %%
df = pd.read_csv('/content/drive/MyDrive/MLStudy/ch03_data_preprocessing/13_file_load_save_data/fruit.csv', usecols=['품목', '크기'])
df.head()
# Out:
#     품목 크기
# 0  바나나  중
# 1  바나나  대
# 2  바나나  중
# 3  토마토  대
# 4  토마토  소

# %% [markdown]
# 파일 저장

# %%
df.to_csv('/content/drive/MyDrive/MLStudy/ch03_data_preprocessing/13_file_load_save_data/write_fruit.csv')
