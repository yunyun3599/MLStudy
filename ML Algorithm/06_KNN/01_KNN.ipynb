# %% [markdown]
# # KNN

# %% [markdown]
# ## KNN 학습 방법과 모델
# ### 모델 학습 방법
# 1. 모델 기반 학습 (Model-Based Learning)
#   - 데이터로부터 모델을 생성하여 분류/예측 진행
#   - Linear Regression, Logistic Regression
# 2. 사례 기반 학습 (Instance-Based Learning)
#   - 별도의 모델 생성 없이 인접 데이터를 분류/예측에 사용
#   - Lazy Learning: 모델을 미리 만들지 않고, 새로운 데이터가 들어오면 계산을 시작
#   - KNN, Naive Bayes

# %% [markdown]
# ## KNN의 정의
# KNN = K-Nearest Neighbors
# - K개의 가까운 이웃을 찾는다
# - 학습 데이터 중 K개의 가장 가까운 사례를 사용하여 분류 및 수치 예측
#
# ### KNN으로 분류 문제를 푸는 방법
# 1. 새로운 데이터를 입력 받음
# 2. 모든 데이터들과의 거리를 계산
# 3. 가장 가까운 K개의 데이터를 선택
# 4. K개 데이터의 클래스를 확인
# 5. 다수의 클래스를 새로운 데이터의 클래스로 예측
#
#
#
# 새로운 데이터와 기존 데이터들간의 거리 계산
#
# ![image.png](data:image/png;base64,...)
#
#
# 가장 가까운 K개의 데이터를 선택 (K=1인 경우)
#
# ![image.png](data:image/png;base64,...)
#
#
# K개 데이터의 클래스를 확인해보면 파란색 0개, 빨간색 1개가 나옴
# 다수의 클래스를 새로운 데이터의 클래스로 예측하므로 새로운 데이터는 빨간색 클래스로 분류됨

# %% [markdown]
# 만약 K=3으로 설정하고 계산을 하면 가장 가까운 3개의 데이터는 아래와 같음
# ![image.png](data:image/png;base64,...)
#
#
# 파란색 2개, 빨간색 1개의 결과가 나오므로 새로운 데이터의 분류 결과는 파란색이 됨

# %% [markdown]
# ## 최적의 K값 설정
# K를 설정하는 것은 KNN 성능에 큰 영향을 미치므로 최적의 K를 선택하는 것은 몹시 중요함
# KNN은 K가 작을 수록 오버피팅이 될 가능성이 높고 K가 클 수록 언더피팅이 될 가능성이 높음
#
# 최적의 K를 구하는 방법은 따로 없고 Cross Validation(교차검증)을 이용해 최적의 K를 구하는 방법을 사용해야함
# (e.g. 1 ~ 10 사이의 K 중 제일 성능이 좋은 K를 선택)
#
# **주의점**
# K는 홀수로 지정해야함
# (짝수의 경우 동점이 발생할 수 있기 때문)

# %% [markdown]
# ## 거리의 종류
# KNN은 데이터간의 거리를 계산하여 가까운 데이터를 찾는데, 이 때 "가깝다"를 판단할 수 있는 거리가 필요함
#
# 거리의 종류로는 아래 2가지가 있음
# 1. 유클리드 거리 (Euclidean Distance)
#   - 두 점 사이의 거리를 계산할 때 흔히 쓰는 방법
#   - 두 점 사이의 최단 거리를 의미함
#   - ![image.png](data:image/png;base64,...)
# 2. 맨해튼 거리 (Manhattan Distance)
#   - 한 번에 한 축 방향으로 움직일 수 있을 때 두 점 사이의 거리
#   - ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## KNN의 장단점
# ### KNN의 장점
# - 학습 과정이 없음
# - 결과를 이해하기 쉬움
#
# ### K-Nearest Neighbors 단점
# - 데이터가 많을 수록 시간이 오래 걸림
# - 지나치게 데이터에 의존적임
