# %% [markdown]
# # displot / hisplot을 이용한 히스토그램 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize': (15, 5)})
import pandas as pd

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## displot

# %%
sns.distplot(df['sepal_length'])
# Out:
# <ipython-input-6-89138501e731>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal_length'])
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# 구간 개수 설정

# %%
sns.distplot(df['sepal_length'], bins=15)
# Out:
# <ipython-input-7-fc52fef2a8fa>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal_length'], bins=15)
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# ## histplot

# %%
sns.histplot(df['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %% [markdown]
# 구간 개수 설정

# %%
sns.histplot(df['sepal_length'], bins=20)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
# kde 옵션 추가
sns.histplot(df['sepal_length'], bins=20, kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
# count를 density로 변경  
sns.histplot(df['sepal_length'], bins=20, kde=True, stat='density')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# 카테고리별 분류

# %%
sns.histplot(data=df, x='sepal_length', bins=20, kde=True, stat='density', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# x축, y축 변경

# %%
sns.histplot(data=df, y='sepal_length', bins=20, kde=True, stat='density', hue='species')
# Out:
# <Axes: xlabel='Density', ylabel='sepal_length'>

# %% [markdown]
# 차원 추가

# %%
sns.histplot(data=df, y='sepal_length', x='sepal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# 칼라바 추가

# %%
sns.histplot(data=df, y='sepal_length', x='sepal_width', cbar=True, hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# ## displot

# %%
sns.displot(df['sepal_length'])

# %%
sns.displot(data=df, x='sepal_length')

# %% [markdown]
# 그림 크기 변경

# %%
sns.displot(data=df, x='sepal_length', height=5, aspect=3)    # width = height * aspect

# %% [markdown]
# histplot과 동일한 옵션 사용

# %%
a = sns.displot(data=df, y='sepal_length', bins=20, kde=True, stat='density', hue='species')

# %%
sns.displot(data=df, y='sepal_length', x='sepal_width', height=5, aspect=3, cbar=True, hue='species')

# %% [markdown]
# ## jointplot

# %%
sns.jointplot(data=df, x='sepal_width', y='sepal_length')

# %% [markdown]
# histplot의 형식으로 변경

# %%
sns.jointplot(data=df, x='sepal_width', y='sepal_length', kind='hist', cbar=True)

# %%
# 그림 크기 변경
sns.jointplot(data=df, x='sepal_width', y='sepal_length', kind='hist', cbar=True, height=10)
